# %%
import pandas as pd

# %%
df = pd.read_csv('t20.csv')

# %%
df
# Out:
#       Sno                   Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       0          V Kohli (INDIA)  2010-2019   75    70  20  2633  94*
# 1       1        RG Sharma (INDIA)  2007-2019  104    96  14  2633  118
# 2       2          MJ Guptill (NZ)  2009-2019   83    80   7  2436  105
# 3       3   Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75
# 4       4         BB McCullum (NZ)  2005-2015   71    70  10  2140  123
# ...   ...                      ...        ...  ...   ...  ..   ...  ...
# 1849   49        H Ssenyondo (UGA)  2019-2019    4     1   1     0   0*
# 1850    0     Taijul Islam (BDESH)  2019-2019    2     1   1     0   0*
# 1851    1       Ziaur Rehman (Fin)  2019-2019    1     1   0     0    0
# 1852    2           M Zondeki (SA)  2006-2006    1     1   0     0    0
# 1853    3  Zulqarnain Haider (ESP)  2019-2019    5     1   0     0    0
#
#         Ave    BF      SR  100  50  0   4s   6s  Unnamed: 15
# ...

# %%
df.drop('Unnamed: 15', axis = 1)
# Out:
#       Sno                   Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       0          V Kohli (INDIA)  2010-2019   75    70  20  2633  94*
# 1       1        RG Sharma (INDIA)  2007-2019  104    96  14  2633  118
# 2       2          MJ Guptill (NZ)  2009-2019   83    80   7  2436  105
# 3       3   Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75
# 4       4         BB McCullum (NZ)  2005-2015   71    70  10  2140  123
# ...   ...                      ...        ...  ...   ...  ..   ...  ...
# 1849   49        H Ssenyondo (UGA)  2019-2019    4     1   1     0   0*
# 1850    0     Taijul Islam (BDESH)  2019-2019    2     1   1     0   0*
# 1851    1       Ziaur Rehman (Fin)  2019-2019    1     1   0     0    0
# 1852    2           M Zondeki (SA)  2006-2006    1     1   0     0    0
# 1853    3  Zulqarnain Haider (ESP)  2019-2019    5     1   0     0    0
#
#         Ave    BF      SR  100  50  0   4s   6s
# 0     52.66  1907  138.07    0  24  2  247   71
# ...

# %%
df.drop('Sno', axis = 1)
# Out:
#                        Player       Span  Mat  Inns  NO  Runs   HS    Ave  \
# 0             V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66
# 1           RG Sharma (INDIA)  2007-2019  104    96  14  2633  118   32.1
# 2             MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36
# 3      Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58
# 4            BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66
# ...                       ...        ...  ...   ...  ..   ...  ...    ...
# 1849        H Ssenyondo (UGA)  2019-2019    4     1   1     0   0*      -
# 1850     Taijul Islam (BDESH)  2019-2019    2     1   1     0   0*      -
# 1851       Ziaur Rehman (Fin)  2019-2019    1     1   0     0    0      0
# 1852           M Zondeki (SA)  2006-2006    1     1   0     0    0      0
# 1853  Zulqarnain Haider (ESP)  2019-2019    5     1   0     0    0      0
#
#         BF      SR  100  50  0   4s   6s  Unnamed: 15
# ...

# %%
df[df['100'] >= 3]
# Out:
#     Sno             Player       Span  Mat  Inns  NO  Runs    HS    Ave    BF  \
# 1     1  RG Sharma (INDIA)  2007-2019  104    96  14  2633   118   32.1  1905
# 23   23   GJ Maxwell (AUS)  2012-2019   61    54   9  1576  145*  35.02   985
# 25   25       C Munro (NZ)  2012-2019   60    57   7  1546  109*  30.92   966
#
#         SR  100  50  0   4s   6s  Unnamed: 15
# 1   138.21    4  19  6  234  120          NaN
# 23     160    3   7  1  133   81          NaN
# 25  160.04    3   9  5  114  100          NaN

# %%
df[df.HS.str.replace('*','').astype(int) >= 50]
# Out:
# /var/folders/85/pz631h490csdlf61sc2z395c0000gp/T/ipykernel_7768/1789074423.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[df.HS.str.replace('*','').astype(int) >= 50]
#      Sno                  Player       Span  Mat  Inns  NO  Runs   HS    Ave  \
# 0      0         V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66
# 1      1       RG Sharma (INDIA)  2007-2019  104    96  14  2633  118   32.1
# 2      2         MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36
# 3      3  Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58
# 4      4        BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66
# ..   ...                     ...        ...  ...   ...  ..   ...  ...    ...
# 705    5     K Birkenstock (NAM)  2019-2019    4     2   0    64   59     32
# ...

# %%
df[df.Ave.str.replace('-','0').astype(float) >= 35.0]['Player'].count()
# Out:
# 101
